# %% [markdown]
# # Link to code:

# %% [markdown]
# # Imports.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(data={
    'a': [1, 2, 3],
    'b': [4, 5, 6]
})

display(df)
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %% [markdown]
# # Question 1.
